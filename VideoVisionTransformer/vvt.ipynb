# %%
# !pip install -qq medmnist

# %%
import os
import io
import imageio
import medmnist
import ipywidgets
import numpy as np
import tensorflow as tf  # for data preprocessing only
import keras
from keras import layers, ops

# Setting seed for reproducibility
SEED = 42
os.environ["TF_CUDNN_DETERMINISTIC"] = "1"
keras.utils.set_random_seed(SEED)

# %%
# DATA
DATASET_NAME = "organmnist3d"
BATCH_SIZE = 32
AUTO = tf.data.AUTOTUNE
INPUT_SHAPE = (28, 28, 28, 1)
NUM_CLASSES = 11

# OPTIMIZER
LEARNING_RATE = 1e-4
WEIGHT_DECAY = 1e-5

# TRAINING
EPOCHS = 60

# TUBELET EMBEDDING
PATCH_SIZE = (8, 8, 8)
NUM_PATCHES = (INPUT_SHAPE[0] // PATCH_SIZE[0]) ** 2

# ViViT ARCHITECTURE
LAYER_NORM_EPS = 1e-6
PROJECTION_DIM = 128
NUM_HEADS = 8
NUM_LAYERS = 8

# %%
def download_and_prepare_dataset(data_info: dict):
    """Utility function to download the dataset.

    Arguments:
        data_info (dict): Dataset metadata.
    """
    data_path = keras.utils.get_file(origin=data_info["url"], md5_hash=data_info["MD5"])

    with np.load(data_path) as data:
        # Get videos
        train_videos = data["train_images"]
        valid_videos = data["val_images"]
        test_videos = data["test_images"]

        # Get labels
        train_labels = data["train_labels"].flatten()
        valid_labels = data["val_labels"].flatten()
        test_labels = data["test_labels"].flatten()

    return (
        (train_videos, train_labels),
        (valid_videos, valid_labels),
        (test_videos, test_labels),
    )


# Get the metadata of the dataset
info = medmnist.INFO[DATASET_NAME]

# Get the dataset
prepared_dataset = download_and_prepare_dataset(info)
(train_videos, train_labels) = prepared_dataset[0]
(valid_videos, valid_labels) = prepared_dataset[1]
(test_videos, test_labels) = prepared_dataset[2]
# Out:
# Downloading data from https://zenodo.org/records/10519652/files/organmnist3d.npz?download=1
# 32657349/32657349 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step

# %%
def preprocess(frames: tf.Tensor, label: tf.Tensor):
    """Preprocess the frames tensors and parse the labels."""
    # Preprocess images
    frames = tf.image.convert_image_dtype(
        frames[
            ..., tf.newaxis
        ],  # The new axis is to help for further processing with Conv3D layers
        tf.float32,
    )
    # Parse label
    label = tf.cast(label, tf.float32)
    return frames, label


def prepare_dataloader(
    videos: np.ndarray,
    labels: np.ndarray,
    loader_type: str = "train",
    batch_size: int = BATCH_SIZE,
):
    """Utility function to prepare the dataloader."""
    dataset = tf.data.Dataset.from_tensor_slices((videos, labels))

    if loader_type == "train":
        dataset = dataset.shuffle(BATCH_SIZE * 2)

    dataloader = (
        dataset.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
        .batch(batch_size)
        .prefetch(tf.data.AUTOTUNE)
    )
    return dataloader


trainloader = prepare_dataloader(train_videos, train_labels, "train")
validloader = prepare_dataloader(valid_videos, valid_labels, "valid")
testloader = prepare_dataloader(test_videos, test_labels, "test")

# %%
class TubeletEmbedding(layers.Layer):
    def __init__(self, embed_dim, patch_size, **kwargs):
        super().__init__(**kwargs)
        self.projection = layers.Conv3D(
            filters=embed_dim,
            kernel_size=patch_size,
            strides=patch_size,
            padding="VALID",
        )
        self.flatten = layers.Reshape(target_shape=(-1, embed_dim))

    def call(self, videos):
        projected_patches = self.projection(videos)
        flattened_patches = self.flatten(projected_patches)
        return flattened_patches

# %%
class PositionalEncoder(layers.Layer):
    def __init__(self, embed_dim, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim

    def build(self, input_shape):
        _, num_tokens, _ = input_shape
        self.position_embedding = layers.Embedding(
            input_dim=num_tokens, output_dim=self.embed_dim
        )
        self.positions = ops.arange(0, num_tokens, 1)

    def call(self, encoded_tokens):
        # Encode the positions and add it to the encoded tokens
        encoded_positions = self.position_embedding(self.positions)
        encoded_tokens = encoded_tokens + encoded_positions
        return encoded_tokens

# %%
def create_vivit_classifier(
    tubelet_embedder,
    positional_encoder,
    input_shape=INPUT_SHAPE,
    transformer_layers=NUM_LAYERS,
    num_heads=NUM_HEADS,
    embed_dim=PROJECTION_DIM,
    layer_norm_eps=LAYER_NORM_EPS,
    num_classes=NUM_CLASSES,
):
    # Get the input layer
    inputs = layers.Input(shape=input_shape)
    # Create patches.
    patches = tubelet_embedder(inputs)
    # Encode patches.
    encoded_patches = positional_encoder(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(transformer_layers):
        # Layer normalization and MHSA
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim // num_heads, dropout=0.1
        )(x1, x1)

        # Skip connection
        x2 = layers.Add()([attention_output, encoded_patches])

        # Layer Normalization and MLP
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        x3 = keras.Sequential(
            [
                layers.Dense(units=embed_dim * 4, activation=ops.gelu),
                layers.Dense(units=embed_dim, activation=ops.gelu),
            ]
        )(x3)

        # Skip connection
        encoded_patches = layers.Add()([x3, x2])

    # Layer normalization and Global average pooling.
    representation = layers.LayerNormalization(epsilon=layer_norm_eps)(encoded_patches)
    representation = layers.GlobalAvgPool1D()(representation)

    # Classify outputs.
    outputs = layers.Dense(units=num_classes, activation="softmax")(representation)

    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=outputs)
    return model

# %%
def run_experiment():
    # Initialize model
    model = create_vivit_classifier(
        tubelet_embedder=TubeletEmbedding(
            embed_dim=PROJECTION_DIM, patch_size=PATCH_SIZE
        ),
        positional_encoder=PositionalEncoder(embed_dim=PROJECTION_DIM),
    )

    # Compile the model with the optimizer, loss function
    # and the metrics.
    optimizer = keras.optimizers.Adam(learning_rate=LEARNING_RATE)
    model.compile(
        optimizer=optimizer,
        loss="sparse_categorical_crossentropy",
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )

    # Train the model.
    _ = model.fit(trainloader, epochs=EPOCHS, validation_data=validloader)

    _, accuracy, top_5_accuracy = model.evaluate(testloader)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")

    return model


model = run_experiment()
# Out:
# Epoch 1/60
# 2025-01-08 16:19:17.885694: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_313', 12 bytes spill stores, 12 bytes spill loads
#
# 2025-01-08 16:19:18.387345: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_4', 16 bytes spill stores, 16 bytes spill loads
#
# 2025-01-08 16:19:18.512597: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_4', 12 bytes spill stores, 12 bytes spill loads
#
# 2025-01-08 16:19:21.182228: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_329', 180 bytes spill stores, 180 bytes spill loads
#
# 2025-01-08 16:19:22.827736: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_329', 284 bytes spill stores, 284 bytes spill loads
# 27/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.1158 - loss: 2.5509 - top-5-accuracy: 0.5756
# 2025-01-08 16:19:38.522884: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_329', 716 bytes spill stores, 716 bytes spill loads
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 49s 669ms/step - accuracy: 0.1187 - loss: 2.5292 - top-5-accuracy: 0.5801 - val_accuracy: 0.1491 - val_loss: 2.2400 - val_top-5-accuracy: 0.6708
# Epoch 2/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.1967 - loss: 2.1987 - top-5-accuracy: 0.7051 - val_accuracy: 0.3602 - val_loss: 1.8883 - val_top-5-accuracy: 0.7826
# Epoch 3/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.2579 - loss: 2.0288 - top-5-accuracy: 0.7845 - val_accuracy: 0.2795 - val_loss: 1.7379 - val_top-5-accuracy: 0.8944
# Epoch 4/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.2872 - loss: 1.8761 - top-5-accuracy: 0.8175 - val_accuracy: 0.3106 - val_loss: 1.4724 - val_top-5-accuracy: 0.9379
# Epoch 5/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.3559 - loss: 1.6620 - top-5-accuracy: 0.8546 - val_accuracy: 0.4224 - val_loss: 1.3478 - val_top-5-accuracy: 0.9503
# Epoch 6/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4095 - loss: 1.4895 - top-5-accuracy: 0.9253 - val_accuracy: 0.4286 - val_loss: 1.3409 - val_top-5-accuracy: 0.9379
# Epoch 7/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4770 - loss: 1.3754 - top-5-accuracy: 0.9363 - val_accuracy: 0.5155 - val_loss: 1.1730 - val_top-5-accuracy: 0.9565
# Epoch 8/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5035 - loss: 1.3249 - top-5-accuracy: 0.9214 - val_accuracy: 0.5776 - val_loss: 0.9474 - val_top-5-accuracy: 0.9814
# Epoch 9/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5563 - loss: 1.1948 - top-5-accuracy: 0.9510 - val_accuracy: 0.5714 - val_loss: 0.9628 - val_top-5-accuracy: 0.9814
# Epoch 10/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5612 - loss: 1.0862 - top-5-accuracy: 0.9664 - val_accuracy: 0.6273 - val_loss: 0.9394 - val_top-5-accuracy: 0.9814
# Epoch 11/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6161 - loss: 0.9950 - top-5-accuracy: 0.9701 - val_accuracy: 0.6708 - val_loss: 0.8750 - val_top-5-accuracy: 0.9876
# Epoch 12/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6295 - loss: 0.9566 - top-5-accuracy: 0.9792 - val_accuracy: 0.6211 - val_loss: 0.9314 - val_top-5-accuracy: 0.9814
# Epoch 13/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6199 - loss: 0.9387 - top-5-accuracy: 0.9801 - val_accuracy: 0.7267 - val_loss: 0.7167 - val_top-5-accuracy: 0.9876
# Epoch 14/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6968 - loss: 0.7965 - top-5-accuracy: 0.9844 - val_accuracy: 0.7143 - val_loss: 0.7753 - val_top-5-accuracy: 0.9938
# Epoch 15/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6946 - loss: 0.8468 - top-5-accuracy: 0.9820 - val_accuracy: 0.7516 - val_loss: 0.6955 - val_top-5-accuracy: 0.9814
# Epoch 16/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7555 - loss: 0.6573 - top-5-accuracy: 0.9930 - val_accuracy: 0.7826 - val_loss: 0.5711 - val_top-5-accuracy: 0.9938
# Epoch 17/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7505 - loss: 0.6570 - top-5-accuracy: 0.9827 - val_accuracy: 0.7702 - val_loss: 0.6186 - val_top-5-accuracy: 0.9938
# Epoch 18/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7575 - loss: 0.6044 - top-5-accuracy: 0.9932 - val_accuracy: 0.8447 - val_loss: 0.4911 - val_top-5-accuracy: 0.9876
# Epoch 19/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8065 - loss: 0.5331 - top-5-accuracy: 0.9978 - val_accuracy: 0.8634 - val_loss: 0.4060 - val_top-5-accuracy: 0.9938
# Epoch 20/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8236 - loss: 0.4736 - top-5-accuracy: 0.9991 - val_accuracy: 0.8323 - val_loss: 0.4490 - val_top-5-accuracy: 1.0000
# Epoch 21/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8503 - loss: 0.4199 - top-5-accuracy: 0.9986 - val_accuracy: 0.8261 - val_loss: 0.4713 - val_top-5-accuracy: 0.9876
# Epoch 22/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8500 - loss: 0.3833 - top-5-accuracy: 0.9987 - val_accuracy: 0.8696 - val_loss: 0.4128 - val_top-5-accuracy: 0.9938
# Epoch 23/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8742 - loss: 0.3647 - top-5-accuracy: 1.0000 - val_accuracy: 0.9068 - val_loss: 0.3403 - val_top-5-accuracy: 1.0000
# Epoch 24/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8763 - loss: 0.3440 - top-5-accuracy: 1.0000 - val_accuracy: 0.8012 - val_loss: 0.5361 - val_top-5-accuracy: 0.9876
# Epoch 25/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8755 - loss: 0.3244 - top-5-accuracy: 0.9960 - val_accuracy: 0.8758 - val_loss: 0.4079 - val_top-5-accuracy: 1.0000
# Epoch 26/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9097 - loss: 0.2498 - top-5-accuracy: 1.0000 - val_accuracy: 0.8199 - val_loss: 0.5153 - val_top-5-accuracy: 0.9938
# Epoch 27/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8803 - loss: 0.3118 - top-5-accuracy: 0.9988 - val_accuracy: 0.8696 - val_loss: 0.4903 - val_top-5-accuracy: 0.9938
# Epoch 28/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8995 - loss: 0.2586 - top-5-accuracy: 1.0000 - val_accuracy: 0.8696 - val_loss: 0.4175 - val_top-5-accuracy: 0.9876
# Epoch 29/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9149 - loss: 0.2448 - top-5-accuracy: 1.0000 - val_accuracy: 0.9130 - val_loss: 0.3553 - val_top-5-accuracy: 1.0000
# Epoch 30/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8940 - loss: 0.2704 - top-5-accuracy: 1.0000 - val_accuracy: 0.8634 - val_loss: 0.4195 - val_top-5-accuracy: 1.0000
# Epoch 31/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9325 - loss: 0.2147 - top-5-accuracy: 1.0000 - val_accuracy: 0.8509 - val_loss: 0.4784 - val_top-5-accuracy: 1.0000
# Epoch 32/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9446 - loss: 0.1645 - top-5-accuracy: 1.0000 - val_accuracy: 0.9068 - val_loss: 0.3523 - val_top-5-accuracy: 1.0000
# Epoch 33/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9750 - loss: 0.1049 - top-5-accuracy: 1.0000 - val_accuracy: 0.9130 - val_loss: 0.3714 - val_top-5-accuracy: 0.9938
# Epoch 34/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9760 - loss: 0.1013 - top-5-accuracy: 1.0000 - val_accuracy: 0.8820 - val_loss: 0.3965 - val_top-5-accuracy: 1.0000
# Epoch 35/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9752 - loss: 0.0958 - top-5-accuracy: 1.0000 - val_accuracy: 0.8758 - val_loss: 0.3303 - val_top-5-accuracy: 1.0000
# Epoch 36/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9612 - loss: 0.0989 - top-5-accuracy: 1.0000 - val_accuracy: 0.8634 - val_loss: 0.4537 - val_top-5-accuracy: 1.0000
# Epoch 37/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9646 - loss: 0.1049 - top-5-accuracy: 1.0000 - val_accuracy: 0.8758 - val_loss: 0.4485 - val_top-5-accuracy: 1.0000
# Epoch 38/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9699 - loss: 0.0952 - top-5-accuracy: 1.0000 - val_accuracy: 0.8385 - val_loss: 0.5338 - val_top-5-accuracy: 1.0000
# Epoch 39/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9611 - loss: 0.1021 - top-5-accuracy: 1.0000 - val_accuracy: 0.8571 - val_loss: 0.5389 - val_top-5-accuracy: 1.0000
# Epoch 40/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9908 - loss: 0.0556 - top-5-accuracy: 1.0000 - val_accuracy: 0.8758 - val_loss: 0.4286 - val_top-5-accuracy: 1.0000
# Epoch 41/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9813 - loss: 0.0591 - top-5-accuracy: 1.0000 - val_accuracy: 0.9193 - val_loss: 0.3368 - val_top-5-accuracy: 0.9938
# Epoch 42/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9936 - loss: 0.0254 - top-5-accuracy: 1.0000 - val_accuracy: 0.8882 - val_loss: 0.4681 - val_top-5-accuracy: 0.9938
# Epoch 43/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9781 - loss: 0.0713 - top-5-accuracy: 1.0000 - val_accuracy: 0.8882 - val_loss: 0.4247 - val_top-5-accuracy: 1.0000
# Epoch 44/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9818 - loss: 0.0626 - top-5-accuracy: 1.0000 - val_accuracy: 0.8882 - val_loss: 0.4271 - val_top-5-accuracy: 1.0000
# Epoch 45/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9631 - loss: 0.0781 - top-5-accuracy: 1.0000 - val_accuracy: 0.9006 - val_loss: 0.4304 - val_top-5-accuracy: 1.0000
# Epoch 46/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9878 - loss: 0.0411 - top-5-accuracy: 1.0000 - val_accuracy: 0.9193 - val_loss: 0.3896 - val_top-5-accuracy: 1.0000
# Epoch 47/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9885 - loss: 0.0491 - top-5-accuracy: 1.0000 - val_accuracy: 0.9068 - val_loss: 0.3280 - val_top-5-accuracy: 1.0000
# Epoch 48/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9855 - loss: 0.0386 - top-5-accuracy: 1.0000 - val_accuracy: 0.8944 - val_loss: 0.4202 - val_top-5-accuracy: 1.0000
# Epoch 49/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9981 - loss: 0.0123 - top-5-accuracy: 1.0000 - val_accuracy: 0.9006 - val_loss: 0.3896 - val_top-5-accuracy: 1.0000
# Epoch 50/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9975 - loss: 0.0125 - top-5-accuracy: 1.0000 - val_accuracy: 0.9130 - val_loss: 0.3828 - val_top-5-accuracy: 0.9938
# Epoch 51/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9970 - loss: 0.0120 - top-5-accuracy: 1.0000 - val_accuracy: 0.8944 - val_loss: 0.4337 - val_top-5-accuracy: 1.0000
# Epoch 52/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0069 - top-5-accuracy: 1.0000 - val_accuracy: 0.9006 - val_loss: 0.3935 - val_top-5-accuracy: 1.0000
# Epoch 53/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9993 - loss: 0.0061 - top-5-accuracy: 1.0000 - val_accuracy: 0.9068 - val_loss: 0.4083 - val_top-5-accuracy: 1.0000
# Epoch 54/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9994 - loss: 0.0066 - top-5-accuracy: 1.0000 - val_accuracy: 0.9130 - val_loss: 0.4311 - val_top-5-accuracy: 1.0000
# Epoch 55/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0050 - top-5-accuracy: 1.0000 - val_accuracy: 0.9130 - val_loss: 0.3610 - val_top-5-accuracy: 1.0000
# Epoch 56/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0020 - top-5-accuracy: 1.0000 - val_accuracy: 0.9130 - val_loss: 0.3807 - val_top-5-accuracy: 1.0000
# Epoch 57/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0018 - top-5-accuracy: 1.0000 - val_accuracy: 0.9193 - val_loss: 0.3833 - val_top-5-accuracy: 1.0000
# Epoch 58/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0017 - top-5-accuracy: 1.0000 - val_accuracy: 0.9193 - val_loss: 0.3899 - val_top-5-accuracy: 1.0000
# Epoch 59/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0015 - top-5-accuracy: 1.0000 - val_accuracy: 0.9193 - val_loss: 0.3907 - val_top-5-accuracy: 1.0000
# Epoch 60/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0014 - top-5-accuracy: 1.0000 - val_accuracy: 0.9130 - val_loss: 0.3889 - val_top-5-accuracy: 1.0000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 174ms/step - accuracy: 0.7710 - loss: 1.0546 - top-5-accuracy: 0.9687
# Test accuracy: 77.7%
# Test top 5 accuracy: 97.21%

# %%
NUM_SAMPLES_VIZ = 25
testsamples, labels = next(iter(testloader))
testsamples, labels = testsamples[:NUM_SAMPLES_VIZ], labels[:NUM_SAMPLES_VIZ]

ground_truths = []
preds = []
videos = []

for i, (testsample, label) in enumerate(zip(testsamples, labels)):
    # Generate gif
    testsample = np.reshape(testsample.numpy(), (-1, 28, 28))
    with io.BytesIO() as gif:
        imageio.mimsave(gif, (testsample * 255).astype("uint8"), "GIF", fps=5)
        videos.append(gif.getvalue())

    # Get model prediction
    output = model.predict(ops.expand_dims(testsample, axis=0))[0]
    pred = np.argmax(output, axis=0)

    ground_truths.append(label.numpy().astype("int"))
    preds.append(pred)


def make_box_for_grid(image_widget, fit):
    """Make a VBox to hold caption/image for demonstrating option_fit values.

    Source: https://ipywidgets.readthedocs.io/en/latest/examples/Widget%20Styling.html
    """
    # Make the caption
    if fit is not None:
        fit_str = "'{}'".format(fit)
    else:
        fit_str = str(fit)

    h = ipywidgets.HTML(value="" + str(fit_str) + "")

    # Make the green box with the image widget inside it
    boxb = ipywidgets.widgets.Box()
    boxb.children = [image_widget]

    # Compose into a vertical box
    vb = ipywidgets.widgets.VBox()
    vb.layout.align_items = "center"
    vb.children = [h, boxb]
    return vb


boxes = []
for i in range(NUM_SAMPLES_VIZ):
    ib = ipywidgets.widgets.Image(value=videos[i], width=100, height=100)
    true_class = info["label"][str(ground_truths[i])]
    pred_class = info["label"][str(preds[i])]
    caption = f"T: {true_class} | P: {pred_class}"

    boxes.append(make_box_for_grid(ib, caption))

ipywidgets.widgets.GridBox(
    boxes, layout=ipywidgets.widgets.Layout(grid_template_columns="repeat(5, 200px)")
)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# GridBox(children=(VBox(children=(HTML(value="'T: pancreas | P: pancreas'"), Box(children=(Image(value=b'GIF89a…
